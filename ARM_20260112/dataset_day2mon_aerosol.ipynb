# %% [markdown]
# ## ENA

# %%
import xarray as xr
import pandas as pd
import os

# 输出目录
out_dir = "/data/ggong/ARM_monthly/ENA/rlproffex1thorC1"
os.makedirs(out_dir, exist_ok=True)

# 需要的变量
vars_to_save = [
    "qc_profile",
    "feature_mask",
    "detection_confidence_score_total",
    "depolarization_ratio",
    "extinction_be",
    "scattering_ratio_e",
    "temperature"
]

# 月份范围
months = pd.date_range("2016-01-01", "2023-12-31", freq="MS")

for t in months:
    year = t.strftime("%Y")
    month = t.strftime("%m")
    
    # 输入文件模式（这个月的所有日文件）
    pattern = f"/data/shared_data/ARM_data/ENA/enarlproffex1thorC1/enarlproffex1thorC1.c0.{year}{month}*.nc"
    
    try:
        # 读入该月数据
        ds = xr.open_mfdataset(pattern, combine="by_coords")
        
        # 高度限制
        ds_sel = ds.sel(height_high=slice(0.03, 8.0))
        
        # 选择变量
        ds_out = ds_sel[vars_to_save]
        
        # 输出文件名
        out_file = os.path.join(out_dir, f"enarlproffex1thorC1.c0.{year}{month}.nc")
        
        # 保存
        ds_out.to_netcdf(out_file)
        print(f"✔ Saved: {out_file}")
    
    except Exception as e:
        print(f"✘ Failed {year}-{month}: {e}")
# Out:
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201601.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201602.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201603.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201604.nc
# ✘ Failed 2016-05: no files to open
# ✘ Failed 2016-06: no files to open
# ✘ Failed 2016-07: no files to open
# ✘ Failed 2016-08: no files to open
# ✘ Failed 2016-09: no files to open
# ✘ Failed 2016-10: no files to open
# ✘ Failed 2016-11: no files to open
# ✘ Failed 2016-12: no files to open
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201701.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201702.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201703.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201704.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201705.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201706.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201707.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201708.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201709.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201710.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201711.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201712.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201801.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201802.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201803.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201804.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201805.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201806.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201807.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201808.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201809.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201810.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201811.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201812.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201901.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201902.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201903.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201904.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201905.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201906.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201907.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201908.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.201909.nc
# ✘ Failed 2019-10: no files to open
# ✘ Failed 2019-11: no files to open
# ✘ Failed 2019-12: no files to open
# ✘ Failed 2020-01: no files to open
# ✘ Failed 2020-02: no files to open
# ✘ Failed 2020-03: no files to open
# ✘ Failed 2020-04: no files to open
# ✘ Failed 2020-05: no files to open
# ✘ Failed 2020-06: no files to open
# ✘ Failed 2020-07: no files to open
# ✘ Failed 2020-08: no files to open
# ✘ Failed 2020-09: no files to open
# ✘ Failed 2020-10: no files to open
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202011.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202012.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202101.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202102.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202103.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202104.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202105.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202106.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202107.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202108.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202109.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202110.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202111.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202112.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202201.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202202.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202203.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202204.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202205.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202206.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202207.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202208.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202209.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202210.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202211.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202212.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202301.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202302.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202303.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202304.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202305.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202306.nc
# ✘ Failed 2023-07: no files to open
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202308.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202309.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202310.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202311.nc
# ✔ Saved: /data/ggong/ARM_monthly/ENA/rlproffex1thorC1/enarlproffex1thorC1.c0.202312.nc

# %% [markdown]
# ## SGP

# %%
import xarray as xr
import pandas as pd
import os

# 输出目录
out_dir = "/data/ggong/ARM_monthly/SGP/rlproffex1thorC1"
os.makedirs(out_dir, exist_ok=True)

# 需要的变量
vars_to_save = [
    "qc_profile",
    "feature_mask",
    "detection_confidence_score_total",
    "depolarization_ratio",
    "extinction_be",
    "scattering_ratio_e",
    "temperature"
]

# 月份范围
months = pd.date_range("2016-01-01", "2023-12-31", freq="MS")

for t in months:
    year = t.strftime("%Y")
    month = t.strftime("%m")
    
    # 输入文件模式（这个月的所有日文件）
    pattern = f"/data/shared_data/ARM_data/SGP/sgprlproffex1thorC1/sgprlproffex1thorC1.c0.{year}{month}*.nc"
    
    try:
        # 读入该月数据
        ds = xr.open_mfdataset(pattern, combine="by_coords")
        
        # 高度限制
        ds_sel = ds.sel(height_high=slice(0.03, 8.0))
        
        # 选择变量
        ds_out = ds_sel[vars_to_save]
        
        # 输出文件名
        out_file = os.path.join(out_dir, f"sgprlproffex1thorC1.c0.{year}{month}.nc")
        
        # 保存
        ds_out.to_netcdf(out_file)
        print(f"✔ Saved: {out_file}")
    
    except Exception as e:
        print(f"✘ Failed {year}-{month}: {e}")
# Out:
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201601.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201602.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201603.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201604.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201605.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201606.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201607.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201608.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201609.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201610.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201611.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201612.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201701.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201702.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201703.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201704.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201705.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201706.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201707.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201708.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201709.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201710.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201711.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201712.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201801.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201802.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201803.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201804.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201805.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201806.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201807.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201808.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201809.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201810.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201811.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201812.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201901.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201902.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201903.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201904.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201905.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201906.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201907.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201908.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201909.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201910.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201911.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.201912.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202001.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202002.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202003.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202004.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202005.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202006.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202007.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202008.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202009.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202010.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202011.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202012.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202101.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202102.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202103.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202104.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202105.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202106.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202107.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202108.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202109.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202110.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202111.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202112.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202201.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202202.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202203.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202204.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202205.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202206.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202207.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202208.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202209.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202210.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202211.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202212.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202301.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202302.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202303.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202304.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202305.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202306.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202307.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202308.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202309.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202310.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202311.nc
# ✔ Saved: /data/ggong/ARM_monthly/SGP/rlproffex1thorC1/sgprlproffex1thorC1.c0.202312.nc
